# %% [markdown]
# processing preprocessed.npz

# %%
from numpy import load

data = load('./data/preprocessed.npz', allow_pickle=True)
lst = data.files

print(data["data"].shape) # (23,)

subj = 0

print(data["data"][subj].keys()) # data, regmat, mvpa 

print(data["data"][subj]["data"].shape) # (1656, 88)
print(data["data"][subj]["regmat"].shape) # (15, 1656) 
print(data["data"][subj]["mvpa"].shape) # (4, 1279) -- how much subj thinks about scenes
# Out:
# (23,)
# dict_keys(['data', 'regmat', 'mvpa'])
# (1656, 88)
# (15, 1656)
# (4, 1279)
